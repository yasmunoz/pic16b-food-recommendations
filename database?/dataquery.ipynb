# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
conn = sqlite3.connect("xfoodz.db")

# %%
recipes = pd.read_csv("jj.csv")

# %%
recipes.head(10)
# Out:
#                                   title  \
# 0                 Traditional Osso Buco
# 1  Italian Sausage Soup with Tortellini
# 2  Italian Sausage, Peppers, and Onions
# 3          Tender Italian Baked Chicken
# 4                    Easy Pizza Sauce I
# 5                   Chef John's Lasagna
# 6                           Panna Cotta
# 7               Easy Italian Chicken II
# 8                      Ethiopian Cheese
# 9                       Easy Lasagna II
#
#                                          ingredients  \
# 0  2 pounds veal shanks, cut into short lengths ,...
# 1  1 pound sweet Italian sausage, casings removed...
# 2  6 (4 ounce) links sweet Italian sausage ,2 tab...
# 3  ¾ cup mayonnaise ,½ cup grated Parmesan cheese...
# 4  1 (6 ounce) can tomato paste ,1 ½ cups water ,...
# 5  1 pound bulk Italian sausage ,1 ½ pounds lean ...
# 6  ⅓ cup skim milk ,1 (.25 ounce) envelope unflav...
# 7  6 skinless, boneless chicken breast halves ,1 ...
# 8  ¼ cup distilled white vinegar ,¼ teaspoon salt...
# 9  1 pound lean ground beef ,1 (32 ounce) jar spa...
#
#                                               recipe                category
# 0  Dust the veal shanks lightly with flour. Melt ...             Main Dishes
# 1  In a 5-quart Dutch oven, brown sausage. Remove...  Vegetable Soup Recipes
# 2  Place the sausage in a large skillet over medi...                 Sausage
# 3  Preheat oven to 425 degrees F (220 degrees C)....                 Italian
# 4  Mix together the tomato paste, water, and oliv...     Pizza Sauce Recipes
# 5  Place sausage and ground beef into a large sau...                 Italian
# 6  Pour milk into a small bowl, and stir in the g...                Desserts
# 7  To Marinate: Pour salad dressing into a large,...                 Breasts
# 8  Bring vinegar and salt to a boil in a saucepan...                 African
# 9  In a large skillet over medium heat brown the ...    Meat Lasagna Recipes

# %%
recipes.to_sql("recipes", conn, if_exists="append", index=False)

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type = 'table'")
print(cursor.fetchall())
# Out:
# [('recipes',)]

# %%
def searcher(ingredientz):
    ingrs = ingredientz.split() 
    #splits the ingredients the user enters into a list
    likey = ""
    for ig in ingrs:
        likey += f"R.ingredients LIKE '%{ig}%' OR "
        #took me the entire afternoon to figure the above line out. :')
        #so that our program returns recipes that include any or all of the ingredients the user specifies. 
    conn = sqlite3.connect("foodz.db")
    query = \
    f"""
    SELECT * FROM recipes R
    WHERE {likey[:-3]} 
    """
    df = pd.read_sql_query(query, conn)
    return df

# %%
searcher("milk flour butter").head(10)
# Out:
#                                           title  \
# 0                            Banana Oat Muffins
# 1                     No-Cook Overnight Oatmeal
# 2  Chocolate Banana Peanut Butter Protein Shake
# 3                        Buttermilk Pancakes II
# 4               Fluffy Microwave Scrambled Eggs
# 5           The Secret to Fluffy Scrambled Eggs
# 6                         Turkish Eggs (Cilbir)
# 7                                   Easy Quiche
# 8                  Creamy Ham and Cheese Quiche
# 9                                 French Crepes
#
#                                          ingredients  \
# 0  1 ½ cups unbleached all-purpose flour ,1 cup r...
# 1  ⅓ cup milk ,¼ cup rolled oats ,¼ cup Greek yog...
# 2  6 cubes ice cubes ,1 cup milk ,1 banana ,1 sco...
# 3  3 cups all-purpose flour ,3 tablespoons white ...
# 4               4 eggs ,¼ cup milk ,⅛ teaspoon salt
# 5   4 large eggs , 1 pinch salt ,4 teaspoons butter
# 6  1 cup Greek yogurt, at room temperature ,1 clo...
# 7  2 cups milk ,4 eggs ,¾ cup biscuit baking mix ...
# 8  1 (9 inch) pastry for a 9-inch pie crust ,1 cu...
# 9  1 cup all-purpose flour ,1 teaspoon white suga...
#
#                                               recipe
# 0  Combine flour, oats, sugar, baking powder, sod...
# 1  Combine milk, oats, Greek yogurt, chia seeds, ...
# 2  Blend ice cubes, milk, banana, protein powder,...
# 3  In a large bowl, combine flour, sugar, baking ...
# 4  Break the eggs into a microwave-proof mixing b...
# 5  Whisk eggs with salt until completely combined...
# 6  Spoon yogurt into a medium bowl. Grate in garl...
# 7  Preheat oven to 375 degrees F (190 degrees C)....
# 8  Preheat oven to 400 degrees F (200 degrees C)....
# 9  Sift together flour, sugar and salt; set aside...
