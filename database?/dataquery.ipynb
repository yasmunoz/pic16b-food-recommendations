# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
conn = sqlite3.connect("foodz.db")

# %%
recipes = pd.read_csv("www.csv")

# %%
recipes.head(10)
# Out:
#                                          title  \
# 0                              Classic Waffles
# 1                     Crustless Spinach Quiche
# 2                         Classic Bran Muffins
# 3                        Scrambled Egg Muffins
# 4                              English Muffins
# 5                  Easy French Toast Casserole
# 6  Chicken Arroz Caldo (Chicken Rice Porridge)
# 7                                Simple Scones
# 8                               Monkey Bread I
# 9              Chef John's Buttermilk Biscuits
#
#                                          ingredients  \
# 0  2 cups all-purpose flour ,1 teaspoon salt ,4 t...
# 1  1 tablespoon vegetable oil ,1 onion, chopped ,...
# 2  1 ½ cups wheat bran ,1 cup buttermilk ,⅓ cup v...
# 3  ½ pound bulk pork sausage ,12 eggs ,½ cup chop...
# 4  1 cup milk ,2 tablespoons white sugar ,1 (.25 ...
# 5  1 cup brown sugar ,½ cup butter ,1 (8 ounce) l...
# 6  2 tablespoons olive oil ,1 onion, diced ,2 clo...
# 7  2 cups all-purpose flour ,⅓ cup sugar ,1 teasp...
# 8  3 (12 ounce) packages refrigerated biscuit dou...
# 9  2 cups all-purpose flour ,2 teaspoons baking p...
#
#                                               recipe
# 0  In a large bowl, mix together flour, salt, bak...
# 1  Preheat oven to 350 degrees F (175 degrees C)....
# 2  Preheat oven to 375 degrees F (190 degrees C)....
# 3  Preheat oven to 350 degrees F (175 degrees C)....
# 4  Warm the milk in a small saucepan until it bub...
# 5  Grease a 9x12-inch baking dish.\nStir 1 cup br...
# 6  Heat the olive oil in a large pot over medium ...
# 7  Adjust oven rack to lower-middle position and ...
# 8  Preheat oven to 350 degrees F (175 degrees C)....
# 9  Preheat oven to 425 degrees F (220 degrees C)....

# %%
recipes.to_sql("recipes", conn, if_exists="append", index=False)

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type = 'table'")
print(cursor.fetchall())
# Out:
# [('recipes',)]

# %%
def rrr(ingredientz):
    ingrs = ingredientz.split() 
    #splits the ingredients the user enters into a list
    likey = ""
    for ig in ingrs:
        likey += f"R.ingredients LIKE '%{ig}%' OR "
        #took me the entire afternoon to figure the above line out. :')
        #so that our program returns recipes that include any or all of the ingredients the user specifies. 
    conn = sqlite3.connect("foodz.db")
    query = \
    f"""
    SELECT * FROM recipes R
    WHERE {likey[:-3]} 
    """
    df = pd.read_sql_query(query, conn)
    return df

# %%
rrr("milk flour butter").head(10)
# Out:
#                                    title  \
# 0                        Classic Waffles
# 1                   Classic Bran Muffins
# 2                        English Muffins
# 3            Easy French Toast Casserole
# 4                          Simple Scones
# 5        Chef John's Buttermilk Biscuits
# 6              Quick and Easy Home Fries
# 7  Baked Ham and Cheese Party Sandwiches
# 8                         Basic Biscuits
# 9          Peanut Butter Banana Smoothie
#
#                                          ingredients  \
# 0  2 cups all-purpose flour ,1 teaspoon salt ,4 t...
# 1  1 ½ cups wheat bran ,1 cup buttermilk ,⅓ cup v...
# 2  1 cup milk ,2 tablespoons white sugar ,1 (.25 ...
# 3  1 cup brown sugar ,½ cup butter ,1 (8 ounce) l...
# 4  2 cups all-purpose flour ,⅓ cup sugar ,1 teasp...
# 5  2 cups all-purpose flour ,2 teaspoons baking p...
# 6  3 medium russet potatoes, cubed ,3 tablespoons...
# 7  ¾ cup melted butter ,1 ½ tablespoons Dijon mus...
# 8  2 cups all-purpose flour ,1 tablespoon baking ...
# 9  2 bananas, broken into chunks ,2 cups milk ,½ ...
#
#                                               recipe
# 0  In a large bowl, mix together flour, salt, bak...
# 1  Preheat oven to 375 degrees F (190 degrees C)....
# 2  Warm the milk in a small saucepan until it bub...
# 3  Grease a 9x12-inch baking dish.\nStir 1 cup br...
# 4  Adjust oven rack to lower-middle position and ...
# 5  Preheat oven to 425 degrees F (220 degrees C)....
# 6  Rinse potato cubes with cold water, and drain ...
# 7  Preheat oven to 350 degrees F (175 degrees C)....
# 8  Preheat oven to 450 degrees F (230 degrees C)....
# 9  Place bananas, milk, peanut butter, honey, and...
